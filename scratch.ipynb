# %%
import pandas as pd

# %%
df_InstLevel = pd.read_excel("college_data/InstLevel.xlsx")
df_InstLevel.head()
# Out:
#    unitid   OPEID                     institution_name  \
# 0  100654  100200             Alabama A & M University
# 1  100663  105200  University of Alabama at Birmingham
# 2  100706  105500  University of Alabama in Huntsville
# 3  100724  100500             Alabama State University
# 4  100751  105100            The University of Alabama
#
#                         addr1_txt addr2_txt    city_txt state_cd     zip_text  \
# 0            4900 Meridian Street       NaN      Normal       AL      35762.0
# 1  Administration Bldg Suite 1070       NaN  Birmingham       AL  352940110.0
# 2                 301 Sparkman Dr       NaN  Huntsville       AL      35899.0
# 3            915 S Jackson Street       NaN  Montgomery       AL  361040271.0
# 4             739 University Blvd       NaN  Tuscaloosa       AL  354870100.0
#
#    ClassificationCode                classification_name  ...  \
# 0                   2                NCAA Division I-FCS  ...
# ...

# %%
df_Schools = pd.read_excel("college_data/Schools.xlsx")
df_Schools.head()
# Out:
#    unitid   OPEID          institution_name             addr1_txt addr2_txt  \
# 0  100654  100200  Alabama A & M University  4900 Meridian Street       NaN
# 1  100654  100200  Alabama A & M University  4900 Meridian Street       NaN
# 2  100654  100200  Alabama A & M University  4900 Meridian Street       NaN
# 3  100654  100200  Alabama A & M University  4900 Meridian Street       NaN
# 4  100654  100200  Alabama A & M University  4900 Meridian Street       NaN
#
#   city_txt state_cd  zip_text  ClassificationCode  classification_name  ...  \
# 0   Normal       AL   35762.0                   2  NCAA Division I-FCS  ...
# 1   Normal       AL   35762.0                   2  NCAA Division I-FCS  ...
# 2   Normal       AL   35762.0                   2  NCAA Division I-FCS  ...
# 3   Normal       AL   35762.0                   2  NCAA Division I-FCS  ...
# 4   Normal       AL   35762.0                   2  NCAA Division I-FCS  ...
#
# ...

# %%
df_InstLevel_NewCols = []
df_School_NewCols = df_Schools.columns

for column in df_InstLevel.columns:
    if column in df_School_NewCols:
        print("Same: {}".format(column))
    else:
        df_InstLevel_NewCols.append(column)
#end
# Out:
# Same: unitid
# Same: OPEID
# Same: institution_name
# Same: addr1_txt
# Same: addr2_txt
# Same: city_txt
# Same: state_cd
# Same: zip_text
# Same: ClassificationCode
# Same: classification_name
# Same: ClassificationOther
# Same: EFMaleCount
# Same: EFFemaleCount
# Same: EFTotalCount
# Same: sector_cd
# Same: sector_name
