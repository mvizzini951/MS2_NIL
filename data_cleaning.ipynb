# %%
import numpy as np
import pandas as pd
import csv

# %%
football_2021 = pd.read_csv("csv_files/football_2021.csv")

# %%
football_2021.head(25)
# Out:
#                   NAME             EXP       POS_HEI_WEI               GRADE  \
# 0        Korey Foreman  2021 - present  EDGE / 6-4 / 265              Junior
# 1            JC Latham  2021 - present    OT / 6-6 / 325              Junior
# 2          Quinn Ewers  2022 - present    QB / 6-3 / 205  Redshirt Sophomore
# 3          Jack Sawyer  2021 - present  EDGE / 6-5 / 248              Junior
# 4       J.T. Tuimoloau  2021 - present  EDGE / 6-5 / 277              Junior
# 5   Tommy Brockermeyer  2023 - present    OT / 6-5 / 292  Redshirt Sophomore
# 6       Caleb Williams  2022 - present    QB / 6-1 / 210              Junior
# 7       Leonard Taylor  2021 - present    DL / 6-4 / 296  Redshirt Sophomore
# 8        Dallas Turner  2021 - present  EDGE / 6-4 / 245              Junior
# 9         Amarius Mims  2021 - present    OT / 6-7 / 330              Junior
# 10        Maason Smith  2021 - present    DL / 6-5 / 316  Redshirt Sophomore
# ...
