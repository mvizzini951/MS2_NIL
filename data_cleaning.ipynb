# %%
import numpy as np
import pandas as pd
import csv
import os

# %%
# df = pd.read_csv("csv_files/basketball_2022.csv")
# df.head(5)

# %%
# df.info()

# %%
#Looks like most of our features have a large number of missing data
#Some of this is expected, not all athletes have instagram, twitter, or tikok as well as NIL deals
#First we should clean the available data into a more coherent structure
#Within our data there are 2 types of missing values, np.nan and '-', we need to handle both of them and convert them to np.nan
#In our age column, for football 2022 one of the unique values is '1819', this is likely an input error in the On3.com database 

#Future Item notes:
# Remove any atheletes who did not go to college (NBA G League)
# 2 seperate cleaned files supervised and unsupervised

# %%
# This function take in a dataframe and cleans all needed columns
def clean_cols(df, sport,rec_year):
    df['POS'] =  [np.nan if (pd.isna(pos) or pos=='-') else pos for pos in df['POS_HEI_WEI'].str.split(' / ').str[0]]
    df['HEIGHT_IN'] = [np.nan if (pd.isna(height) or height=='-') else (float(height.split('-')[0])*12 + float(height.split('-')[1])) for height in df['POS_HEI_WEI'].str.split(' / ').str[1]]
    df['WEIGHT_LBS'] = [np.nan if (pd.isna(weight) or weight=='-') else float(weight) for weight in df['POS_HEI_WEI'].str.split(' / ').str[2]]
    df['SKILL_'] = [np.nan if pd.isna(skill) else skill if type(skill)==float else float(skill[0:-1]) if skill[-1]=='+' else float(skill) for skill in df['SKILL']]
    df['COLLDIST_MI'] = [np.nan if (pd.isna(dist) or dist=='-') else float(dist.split()[0]) for dist in df['COLLDIST']]
    df['NILVAL_LONG_USD'] = [np.nan if pd.isna(nilval) else float(nilval[1:-1])*1000000 if nilval[-1]=='M' else float(nilval[1:-1])*1000 if nilval[-1]=='K' else float(nilval[1:-1]) for nilval in df['NILVAL']]
    df['INSTA_LONG'] = [np.nan if (pd.isna(insta) or insta == '-') else float(insta[0:-1])*1000000 if insta[-1]=='M' else float(insta[0:-1])*1000 if insta[-1]=='K' else float(insta) for insta in df['INSTA']]
    df['TWIT_LONG'] = [np.nan if (pd.isna(twit) or twit == '-') else float(twit[0:-1])*1000000 if twit[-1]=='M' else float(twit[0:-1])*1000 if twit[-1]=='K' else float(twit) for twit in df['TWIT']]
    df['TIK_LONG'] = [np.nan if (pd.isna(tik) or tik == '-') else float(tik[0:-1])*1000000 if tik[-1]=='M' else float(tik[0:-1])*1000 if tik[-1]=='K' else float(tik) for tik in df['TIK']]
    df['STATE'] = [np.nan if (pd.isna(ht) or ht=='-') else ht[-3:] for ht in df['HOTOWN']]
    df['SPORT'] = sport
    df['RECRUIT_YEAR'] = rec_year
    return df

# %%
directory = 'csv_files'
bball_count = 0
fball_count = 0

for file in os.listdir(directory):
    f = os.path.join(directory, file)
    df = pd.read_csv(f)
    sport = file.split('_')[0]
    year = file.split('_')[-1].split('.')[0]
    if sport == 'basketball':
        if bball_count == 0:
            bball_clean = clean_cols(df,sport,year)
            bball_count += 1
        else:
            bball_clean = pd.concat([bball_clean,clean_cols(df,sport,year)])
            bball_count += 1
    elif sport == 'football':
        if fball_count == 0:
            fball_clean = clean_cols(df,sport,year)
            fball_count += 1
        else:
            fball_clean = pd.concat([fball_clean,clean_cols(df,sport,year)])
            fball_count += 1
        
print("{} basketball data files cleaned and merged together".format(bball_count))
print("{} footballall data files cleaned and merged together".format(fball_count))
bball_clean.to_csv('cleaned_files/basketball_clean.csv')
fball_clean.to_csv('cleaned_files/football_clean.csv')
# Out:
# 6 basketball data files cleaned and merged together
# 6 footballall data files cleaned and merged together

# %%
dropnafball = fball_clean.dropna(subset=['NILVAL_LONG_USD'])
dropnafball.sample(25)
# Out:
#                  NAME             EXP         POS_HEI_WEI               GRADE  \
# 280    R Mason Thomas  2022 - present    DL / 6-1.5 / 215           Sophomore
# 263         Trey Zuhn  2021 - present      OT / 6-6 / 300  Redshirt Sophomore
# 94    Joseph Phillips             NaN    LB / 6-1.5 / 250                 NaN
# 138    Garrett Stover             NaN      LB / 6-0 / 205                 NaN
# 45     Chase Bisontis  2023 - present   IOL / 6-4.5 / 315            Freshman
# 111     Jaden Nickens             NaN      WR / 6-3 / 170                 NaN
# 72          Casey Poe             NaN   IOL / 6-4.5 / 290                 NaN
# 120    Tackett Curtis  2023 - present    LB / 6-2.5 / 220            Freshman
# 304      Aaron Bryant  2022 - present      DL / 6-3 / 290   Redshirt Freshman
# 192   Terhyon Nichols             NaN   CB / 5-10.5 / 185                 NaN
# 225    Sydir Mitchell  2023 - present      DL / 6-6 / 320            Freshman
# 89      Caleb Herring  2023 - present    EDGE / 6-5 / 220            Freshman
# 6        Savion Hiter             NaN   RB / 5-11.5 / 190                 NaN
# 7      Leonard Taylor  2021 - present      DL / 6-4 / 296  Redshirt Sophomore
# 346     Tanner Bailey  2022 - present      QB / 6-1 / 189   Redshirt Freshman
# 110   Darrius Clemons  2022 - present      WR / 6-3 / 205           Sophomore
# 270     Xadavien Sims             NaN      DL / 6-3 / 280                 NaN
# 11        Cam Coleman             NaN    WR / 6-3.5 / 185                 NaN
# 180        CJ Jackson             NaN  EDGE / 6-3.5 / 220                 NaN
# 274     Bryson Nesbit  2021 - present      TE / 6-6 / 235              Junior
# 863     Jake Appleget  2022 - present      TE / 6-4 / 220   Redshirt Freshman
# 138          AJ Green  2021 - present     RB / 5-11 / 194              Junior
# 8     Kendre Harrison             NaN     ATH / 6-7 / 230                 NaN
# 174  Donovan McMillon  2023 - present       S / 6-2 / 193              Junior
# 249     Kingston Lopa             NaN       S / 6-3 / 195                 NaN
#
#      AGE  SKILL              HISCH               HOTOWN        STARCOLL  \
# 280   19  90.38   Cardinal Gibbons  Fort Lauderdale, FL        Oklahoma
# 263   20  90.86       Fossil Ridge     Fort Collins, CO       Texas A&M
# 94   NaN  93.39                NaN                  NaN          Auburn
# 138  NaN  92.54                NaN                  NaN      Ohio State
# 45    19  96.40     Don Bosco Prep           Ramsey, NJ       Texas A&M
# 111  NaN  92.11                NaN                  NaN        Oklahoma
# 72   NaN  93.98                NaN                  NaN         Alabama
# 120   19  93.62               Many             Many, LA             USC
# 304   19  90.08          Southaven        Southaven, MS           Texas
# 192  NaN  91.44                NaN                  NaN        Kentucky
# 225    -  91.59    Bergen Catholic          Oradell, NJ           Texas
# 89    18  94.47          Riverdale     Murfreesboro, TN       Tennessee
# 6    NaN   92.9                NaN                  NaN        Virginia
# 7     21  98.68     Miami Palmetto            Miami, FL           Miami
# 346   20  89.74              Gordo            Gordo, AL  South Carolina
# 110   20  94.04           Westview         Portland, OR        Michigan
# 270  NaN  90.41                NaN                  NaN          Oregon
# 11   NaN  98.15                NaN                  NaN       Texas A&M
# 180  NaN  91.66                NaN                  NaN    Georgia Tech
# 274   21  90.64  South Mecklenburg        Charlotte, NC  North Carolina
# 863   20  85.75  Lincoln Southeast          Lincoln, NE        Syracuse
# 138   20  92.92              Union            Tulsa, OK        Arkansas
# 8    NaN  92.71                NaN                  NaN        NC State
# 174   21  92.27    Peters Township       Canonsburg, PA         Florida
# 249  NaN  90.60                NaN                  NaN          Oregon
#
#      COLLDIST  ...  WEIGHT_LBS SKILL_ COLLDIST_MI NILVAL_LONG_USD INSTA_LONG  \
# 280  1195 mi.  ...       215.0  90.38      1195.0         65000.0     2800.0
# 263   848 mi.  ...       300.0  90.86       848.0         72000.0     1500.0
# 94     15 mi.  ...       250.0  93.39        15.0        122000.0      850.0
# 138    14 mi.  ...       205.0  92.54        14.0        106000.0     2700.0
# 45   1430 mi.  ...       315.0  96.40      1430.0        193000.0    15300.0
# 111    22 mi.  ...       170.0  92.11        22.0         77000.0    12700.0
# 72    453 mi.  ...       290.0  93.98       453.0        122000.0     2200.0
# 120  1443 mi.  ...       220.0  93.62      1443.0        148000.0     3700.0
# 304   556 mi.  ...       290.0  90.08       556.0        168000.0        NaN
# 192    76 mi.  ...       185.0  91.44        76.0         78000.0        NaN
# 225  1516 mi.  ...       320.0  91.59      1516.0        144000.0     8700.0
# 89    135 mi.  ...       220.0  94.47       135.0        143000.0     6100.0
# 6      38 mi.  ...       190.0  92.90        38.0        111000.0     1500.0
# 7       5 mi.  ...       296.0  98.68         5.0        255000.0    14700.0
# 346   399 mi.  ...       189.0  89.74       399.0         73000.0    12300.0
# 110  1928 mi.  ...       205.0  94.04      1928.0         85000.0    22000.0
# 270  1583 mi.  ...       280.0  90.41      1583.0         61000.0     2900.0
# 11    677 mi.  ...       185.0  98.15       677.0        316000.0     6200.0
# 180    13 mi.  ...       220.0  91.66        13.0         75000.0     1700.0
# 274   113 mi.  ...       235.0  90.64       113.0        105000.0     9700.0
# 863     0 mi.  ...       220.0  85.75         0.0         63000.0     1500.0
# 138   113 mi.  ...       194.0  92.92       113.0         64000.0    16500.0
# 8      68 mi.  ...       230.0  92.71        68.0        113000.0     2700.0
# 174   744 mi.  ...       193.0  92.27       744.0         77000.0    52000.0
# 249   388 mi.  ...       195.0  90.60       388.0         71000.0     4000.0
#
#     TWIT_LONG  TIK_LONG  STATE     SPORT  RECRUIT_YEAR
# 280    3200.0       NaN     FL  football          2022
# 263    1700.0       NaN     CO  football          2021
# 94     1200.0     110.0    NaN  football          2024
# 138    2800.0     599.0    NaN  football          2024
# 45     5300.0    3100.0     NJ  football          2023
# 111    1900.0    4300.0    NaN  football          2025
# 72     3000.0     101.0    NaN  football          2024
# 120    6300.0    1200.0     LA  football          2023
# 304    2200.0     200.0     MS  football          2022
# 192    1500.0     375.0    NaN  football          2024
# 225    4100.0    1300.0     NJ  football          2023
# 89     3500.0      46.0     TN  football          2023
# 6      1200.0       NaN    NaN  football          2026
# 7     12700.0     912.0     FL  football          2021
# 346    5000.0    2100.0     AL  football          2022
# 110    8300.0   11000.0     OR  football          2022
# 270    5000.0     776.0    NaN  football          2024
# 11     3000.0       NaN    NaN  football          2024
# 180    1400.0       NaN    NaN  football          2024
# 274    1300.0     228.0     NC  football          2021
# 863    1600.0     178.0     NE  football          2022
# 138    7700.0       NaN     OK  football          2021
# 8      2300.0       NaN    NaN  football          2026
# 174    9600.0   71000.0     PA  football          2021
# 249    1200.0       NaN    NaN  football          2024
#
# [25 rows x 27 columns]

# %%
dropnabball = bball_clean.dropna(subset=['NILVAL_LONG_USD'])
dropnabball.sample(25)
# Out:
#                      NAME             EXP      POS_HEI_WEI              GRADE  \
# 21        Elmarko Jackson  2023 - present   PG / 6-4 / 200           Freshman
# 43            Kobe Bufkin             NaN   SG / 6-4 / 175                NaN
# 49         Kanaan Carlyle  2023 - present   CG / 6-2 / 175           Freshman
# 208       Hansel Enmanuel             NaN   CG / 6-4 / 175                NaN
# 3          Shaedon Sharpe             NaN   SG / 6-4 / 175                NaN
# 48           DaRon Holmes             NaN   PF / 6-8 / 195                NaN
# 14          Cayden Boozer             NaN   PG / 6-3 / 190                NaN
# 24      Matthew Cleveland  2023 - present   CG / 6-6 / 190             Junior
# 17            JJ Starling  2023 - present   SG / 6-4 / 200          Sophomore
# 8          Alex Constanza             NaN   SG / 6-8 / 175                NaN
# 22           Yohan Traore  2023 - present  PF / 6-10 / 225          Sophomore
# 34   DeShawn Harris-Smith  2023 - present   SG / 6-5 / 205           Freshman
# 2           Brandon McCoy             NaN     PG / 6-4 / -                NaN
# 18          Ikenna Alozie             NaN   SG / 6-3 / 185                NaN
# 18           Isaiah Evans             NaN   SF / 6-6 / 165                NaN
# 49           Dior Johnson  2022 - present   PG / 6-2 / 180  Redshirt Freshman
# 28                MJ Rice  2023 - present   SF / 6-5 / 215          Sophomore
# 10           Drake Powell             NaN   SF / 6-6 / 185                NaN
# 39        Naas Cunningham             NaN   SF / 6-7 / 180                NaN
# 77       Mike Sharavjamts             NaN   SF / 6-8 / 180                NaN
# 4           Matas Buzelis             NaN  SF / 6-10 / 190                NaN
# 32            Mookie Cook  2023 - present   SF / 6-7 / 200           Freshman
# 42       Rakease Passmore             NaN   SF / 6-5 / 185                NaN
# 12         Jasper Johnson             NaN   CG / 6-2 / 165                NaN
# 4             Emoni Bates             NaN  SF / 6-10 / 200                NaN
#
#      AGE   SKILL                        HISCH               HOTOWN  \
# 21    19   97.15            South Kent School          Marlton, NJ
# 43   NaN   96.18       Grand Rapids Christian     Grand Rapids, MI
# 49     -   95.55               Overtime Elite       Alpharetta, GA
# 208  NaN   86.00                 Life Academy        Kissimmee, FL
# 3    NaN  99.52+         Dream City Christian         Glendale, AZ
# 48     -   95.77            Montverde Academy        Montverde, FL
# 14   NaN   97.45                          NaN                  NaN
# 24     -   97.77                 Pace Academy       Alpharetta, GA
# 17     -  98.34+            La Lumiere School    Baldwinsville, NY
# 8    NaN   98.05                          NaN                  NaN
# 22     -   98.02         Dream City Christian             Napa, CA
# 34     -   96.44             Paul VI Catholic          Fairfax, VA
# 2    NaN   98.96                          NaN                  NaN
# 18   NaN   96.75                          NaN                  NaN
# 18   NaN   97.93                          NaN                  NaN
# 49     -   95.47  Southern California Academy           Corona, CA
# 28     -   97.39                Prolific Prep  Mouth Of Wilson, VA
# 10   NaN   98.52                          NaN                  NaN
# 39   NaN   95.66                          NaN                  NaN
# 77   NaN   93.67                  ISA Academy       Willoughby, OH
# 4      -  99.25+            Sunrise Christian          Chicago, IL
# 32     -   96.59                 Compass Prep        Jefferson, OR
# 42   NaN   95.62                          NaN                  NaN
# 12   NaN   97.82                          NaN                  NaN
# 4    NaN  99.40+            Ypsi Prep Academy        Ypsilanti, MI
#
#                STARCOLL  COLLDIST  ...  HEIGHT_IN WEIGHT_LBS SKILL_  \
# 21               Kansas  1082 mi.  ...       76.0      200.0  97.15
# 43             Michigan   103 mi.  ...       76.0      175.0  96.18
# 49             Stanford  2121 mi.  ...       74.0      175.0  95.55
# 208  Northwestern State   765 mi.  ...       76.0      175.0  86.00
# 3              Kentucky  1577 mi.  ...       76.0      175.0  99.52
# 48               Dayton   785 mi.  ...       80.0      195.0  95.77
# 14              Florida   292 mi.  ...       75.0      190.0  97.45
# 24        Florida State   257 mi.  ...       78.0      190.0  97.77
# 17           Notre Dame   515 mi.  ...       76.0      200.0  98.34
# 8               Florida   278 mi.  ...       80.0      175.0  98.05
# 22               Auburn  2087 mi.  ...       82.0      225.0  98.02
# 34             Maryland    25 mi.  ...       77.0      205.0  96.44
# 2                   USC     9 mi.  ...       76.0        NaN  98.96
# 18           Providence  5136 mi.  ...       75.0      185.0  96.75
# 18                 Duke   117 mi.  ...       78.0      165.0  97.93
# 49           Pittsburgh  2102 mi.  ...       74.0      180.0  95.47
# 28               Kansas   770 mi.  ...       77.0      215.0  97.39
# 10       North Carolina    18 mi.  ...       78.0      185.0  98.52
# 39        West Virginia   315 mi.  ...       79.0      180.0  95.66
# 77               Dayton   196 mi.  ...       80.0      180.0  93.67
# 4          NBA G League  1835 mi.  ...       82.0      190.0  99.25
# 32               Oregon    48 mi.  ...       79.0      200.0  96.59
# 42          Wake Forest   453 mi.  ...       77.0      185.0  95.62
# 12        West Virginia   264 mi.  ...       74.0      165.0  97.82
# 4               Memphis   597 mi.  ...       82.0      200.0  99.40
#
#     COLLDIST_MI NILVAL_LONG_USD INSTA_LONG  TWIT_LONG  TIK_LONG  STATE  \
# 21       1082.0        121000.0    12900.0     2300.0       NaN     NJ
# 43        103.0        103000.0    13000.0     3600.0       NaN     MI
# 49       2121.0         69000.0    18600.0      634.0       3.0     GA
# 208       765.0       1200000.0  1600000.0        NaN       NaN     FL
# 3        1577.0         74000.0        NaN        NaN       NaN     AZ
# 48        785.0         91000.0    12400.0     4100.0    3000.0     FL
# 14        292.0        187000.0    40000.0        NaN   15900.0    NaN
# 24        257.0        217000.0    13000.0     2900.0      45.0     GA
# 17        515.0        117000.0    15800.0        NaN    2000.0     NY
# 8         278.0        142000.0     2900.0      278.0       NaN    NaN
# 22       2087.0        163000.0     8200.0     4000.0       NaN     CA
# 34         25.0         67000.0     8900.0     1700.0    2800.0     VA
# 2           9.0        182000.0    10700.0      512.0    4900.0    NaN
# 18       5136.0         75000.0     3800.0      175.0     240.0    NaN
# 18        117.0        208000.0     1100.0     3600.0       NaN    NaN
# 49       2102.0        157000.0   512000.0    36000.0   24000.0     CA
# 28        770.0        119000.0    55000.0     3500.0     204.0     VA
# 10         18.0        304000.0        NaN     1900.0       NaN    NaN
# 39        315.0         83000.0    39000.0     1800.0       NaN    NaN
# 77        196.0        121000.0   199000.0     5700.0      58.0     OH
# 4        1835.0        583000.0    71000.0     3300.0     931.0     IL
# 32         48.0         90000.0    43000.0     2300.0    7500.0     OR
# 42        453.0         64000.0    11600.0     1800.0     210.0    NaN
# 12        264.0        154000.0        NaN     2300.0       NaN    NaN
# 4         597.0        457000.0   459000.0    29000.0   14200.0     MI
#
#           SPORT
# 21   basketball
# 43   basketball
# 49   basketball
# 208  basketball
# 3    basketball
# 48   basketball
# 14   basketball
# 24   basketball
# 17   basketball
# 8    basketball
# 22   basketball
# 34   basketball
# 2    basketball
# 18   basketball
# 18   basketball
# 49   basketball
# 28   basketball
# 10   basketball
# 39   basketball
# 77   basketball
# 4    basketball
# 32   basketball
# 42   basketball
# 12   basketball
# 4    basketball
#
# [25 rows x 26 columns]

# %%
df_schools = pd.read_excel("college_data/Schools.xlsx")
df_schools = df_schools[df_schools['Sports'].isin(['Basketball','Football'])]

# %%
df_schools.sample(10)
# Out:
#        unitid    OPEID                           institution_name  \
# 15847  232089   371100                             Ferrum College
# 9826   190600   269300  CUNY John Jay College of Criminal Justice
# 11522  199971  3570300                 Carolina Christian College
# 14375  219082   346300                    Dakota State University
# 3135   137564   152100                    Southeastern University
# 4472   150668   179900                             Goshen College
# 6475   164270   210900                           McDaniel College
# 12384  207263   316100              Northeastern State University
# 104    101189   100300                        Faulkner University
# 13737  216357   337600                              Thiel College
#
#                       addr1_txt addr2_txt       city_txt state_cd  \
# 15847  215 Ferrum Mountain Road       NaN         Ferrum       VA
# 9826              524 W 59th St       NaN       New York       NY
# 11522       4209 Indiana Avenue       NaN  Winston Salem       NC
# 14375      820 N Washington Ave       NaN        Madison       SD
# 3135       1000 Longfellow Blvd       NaN       Lakeland       FL
# 4472             1700 S Main St       NaN         Goshen       IN
# 6475             2 College Hill       NaN    Westminster       MD
# 12384               600 N Grand       NaN      Tahlequah       OK
# 104            5345 Atlanta Hwy       NaN     Montgomery       AL
# 13737            75 College Ave       NaN     Greenville       PA
#
#           zip_text  ClassificationCode                 classification_name  \
# 15847  240889000.0                   6     NCAA Division III with football
# 9826       10019.0                   7  NCAA Division III without football
# 11522      27105.0                   8                               Other
# 14375  570421799.0                   9                     NAIA Division I
# 3135   338016034.0                   9                     NAIA Division I
# 4472   465264794.0                  10                    NAIA Division II
# 6475       21157.0                   6     NCAA Division III with football
# 12384  744642399.0                   4      NCAA Division II with football
# 104    361093390.0                   9                     NAIA Division I
# 13737  161252181.0                   6     NCAA Division III with football
#
#        ...    EXP_MEN  EXP_WOMEN  TOTAL_EXP_MENWOMEN  EXP_COED_MEN  \
# 15847  ...   167816.0   190244.0            358060.0           NaN
# 9826   ...    48154.0    47915.0             96069.0           NaN
# 11522  ...   380548.0   325691.0            706239.0           NaN
# 14375  ...   291766.0   307881.0            599647.0           NaN
# 3135   ...  1869226.0        NaN           1869226.0           NaN
# 4472   ...   331265.0   438853.0            770118.0           NaN
# 6475   ...   152185.0   154801.0            306986.0           NaN
# 12384  ...  1597573.0        NaN           1597573.0           NaN
# 104    ...  1682989.0        NaN           1682989.0           NaN
# 13737  ...   132705.0   133919.0            266624.0           NaN
#
#        EXP_COED_WOMEN TOTAL_EXP_COED  EXPENSE_MENALL  EXPENSE_WOMENALL  \
# 15847             NaN            NaN          167816            190244
# 9826              NaN            NaN           48154             47915
# 11522             NaN            NaN          380548            325691
# 14375             NaN            NaN          291766            307881
# 3135              NaN            NaN         1869226                 0
# 4472              NaN            NaN          331265            438853
# 6475              NaN            NaN          152185            154801
# 12384             NaN            NaN         1597573                 0
# 104               NaN            NaN         1682989                 0
# 13737             NaN            NaN          132705            133919
#
#        TOTAL_EXPENSE_ALL      Sports
# 15847             358060  Basketball
# 9826               96069  Basketball
# 11522             706239  Basketball
# 14375             599647  Basketball
# 3135             1869226    Football
# 4472              770118  Basketball
# 6475              306986  Basketball
# 12384            1597573    Football
# 104              1682989    Football
# 13737             266624  Basketball
#
# [10 rows x 129 columns]
